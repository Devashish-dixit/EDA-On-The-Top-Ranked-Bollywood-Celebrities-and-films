# %% [markdown]
# ![](https://img1.picmix.com/output/stamp/normal/9/4/7/3/1953749_59e4e.png)

# %% [markdown]
# # Analysis On The Top Ranked Bollywood Celebrities
#
# Bollywood is the Hindi film industry based in Mumbai, India. It is the largest film industry in the world in terms of the number of films produced and the number of people employed.In this analysis, I will explore the Bollywood Actors Ranking dataset through visualizations and graphs using matplotlib and seaborn.

# %% [markdown]
# ## Package Install and Import
# First, we will install and import necessary packages.

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import matplotlib

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
project_name = "analysis-on-the-top-ranked-bollywood-celebrities"

# %%
jovian.commit(files=['BollywoodActorRanking.csv','BollywoodMovieDetail.csv'],project=project_name)
# Out:
# [jovian] Updating notebook "devashish-dixit/analysis-on-the-top-ranked-bollywood-celebrities" on https://jovian.com
# [jovian] Uploading additional files...
# [jovian] Committed successfully! https://jovian.com/devashish-dixit/analysis-on-the-top-ranked-bollywood-celebrities
# 'https://jovian.com/devashish-dixit/analysis-on-the-top-ranked-bollywood-celebrities'

# %% [markdown]
# ## Loading the Dataset
#
# We are now prepared to load the dataset, which we will accomplish by utilizing the standard "read_csv" function from the Pandas library. Let us have a quick look at the data to get an idea of its appearance.

# %%
Bollywood_df = pd.read_csv('BollywoodActorRanking.csv')
Bollywood_df.head(10)
# Out:
#    actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 0      373        Aamir Khan          11       1170              9.44862
# 1      374    Shah Rukh Khan          23       2000              7.55009
# 2      375       Salman Khan          36       2340              5.40217
# 3      376      Katrina Kaif          17       1640              8.48082
# 4      377  Deepika Padukone          16       1080              5.64674
# 5      378    Hrithik Roshan          16       1120              5.89130
# 6      379   Priyanka Chopra          36       1990              4.45109
# 7      380    Kareena Kapoor          37       2200              4.86016
# 8      381     Ranbir Kapoor          11        890              6.95850
# 9      382             Kajol           6        450              6.38043
#
#    googleHits  normalizedGoogleRank  normalizedRating
# 0     2460000               7.34283          10.00000
# 1     2670000               7.88458           9.22674
# 2     3490000              10.00000           9.20821
# 3     2120000               6.46570           8.94852
# 4     3000000               8.73591           8.62716
# 5     2650000               7.83298           8.25194
# 6     3130000               9.07128           8.13686
# 7     2940000               8.58112           8.09065
# 8     1860000               5.79496           7.69864
# 9     1780000               5.58858           7.25156

# %% [markdown]
# After a quick look at the dataset, it looks like a typical celebrity performance dataset with ratings and ranks between the year  2001 and 2014.

# %% [markdown]
# ## Data Preparation and Cleaning

# %%
Bollywood_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   actorId               301 non-null    int64
#  1   actorName             301 non-null    object
#  2   movieCount            301 non-null    int64
#  3   ratingSum             301 non-null    int64
#  4   normalizedMovieRank   301 non-null    float64
#  5   googleHits            301 non-null    int64
#  6   normalizedGoogleRank  189 non-null    float64
#  7   normalizedRating      301 non-null    float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 18.9+ KB

# %% [markdown]
# There are 301 entries and 8 columns to work with. As we can see , there is a columns that contain null values
# ('normalizedGoogleRank').

# %%
Bollywood_df.nunique()
# Out:
# actorId                 301
# actorName               301
# movieCount               36
# ratingSum                96
# normalizedMovieRank     157
# googleHits              178
# normalizedGoogleRank    177
# normalizedRating        224
# dtype: int64

# %% [markdown]
# ## Handling Null Values
# We can see that for each of the columns, there are some different unique values for some of them. It makes sense that actorId contains 301 distinct values, since it is a unique key used to identify an actor.

# %%
Bollywood_df.isnull().values.any()
# Out:
# True

# %%
Bollywood_df.isnull().sum().sum()
# Out:
# 112

# %%
sns.heatmap(Bollywood_df.isnull(), cbar=False)
plt.title('Null Values Heatmap')
plt.show()

# %% [markdown]
# As it is evident from the heatmap above,there are a lot of null values present in normalizedGoogleRank .Let us see the specifications of these parameters.

# %%
Bollywood_df.isnull().sum()
# Out:
# actorId                   0
# actorName                 0
# movieCount                0
# ratingSum                 0
# normalizedMovieRank       0
# googleHits                0
# normalizedGoogleRank    112
# normalizedRating          0
# dtype: int64

# %% [markdown]
# As stated in the table, we can see that there are quite a few null values in the dataset. There are a total of 112 null values  missing points under 'normalizedGoogleRank' . We will have to handle all null data points before we move further.

# %% [markdown]
# For null values, the easiest way to get rid of them is to delete the columns with the missing data and as we had another ranking parameter known as delete "normalizedMovieRank",we afford to delete the "normalizedGoogleRank" column.

# %%
Bollywood_df = Bollywood_df.drop('normalizedGoogleRank', axis=1)

# %%
Bollywood_df.isnull().any()
# Out:
# actorId                False
# actorName              False
# movieCount             False
# ratingSum              False
# normalizedMovieRank    False
# googleHits             False
# normalizedRating       False
# dtype: bool

# %%
Bollywood_df.head(10)
# Out:
#    actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 0      373        Aamir Khan          11       1170              9.44862
# 1      374    Shah Rukh Khan          23       2000              7.55009
# 2      375       Salman Khan          36       2340              5.40217
# 3      376      Katrina Kaif          17       1640              8.48082
# 4      377  Deepika Padukone          16       1080              5.64674
# 5      378    Hrithik Roshan          16       1120              5.89130
# 6      379   Priyanka Chopra          36       1990              4.45109
# 7      380    Kareena Kapoor          37       2200              4.86016
# 8      381     Ranbir Kapoor          11        890              6.95850
# 9      382             Kajol           6        450              6.38043
#
#    googleHits  normalizedRating
# 0     2460000          10.00000
# 1     2670000           9.22674
# 2     3490000           9.20821
# 3     2120000           8.94852
# 4     3000000           8.62716
# 5     2650000           8.25194
# 6     3130000           8.13686
# 7     2940000           8.09065
# 8     1860000           7.69864
# 9     1780000           7.25156

# %% [markdown]
# ## Adding another dataset
# we will be casually using the Bollywood Movie Detail dataset which contain very useful data about the movies which these actors were as cast.The hitFlop column contains values from 1 to 9 with
#
# 1 - Disaster 2 - Flop 3 - Below Average 4 - Average 5 - Semi Hit 6 - Hit 7 - Super Hit 8 - Blockbuster 9 - All-Time Blockbuster.
#
# The following dataset is much bigger than the first dataset. So,let us give it a look.

# %%
movies_df=pd.read_csv("BollywoodMovieDetail.csv")

# %%
movies_df.head(10)
# Out:
#       imdbId                              title  releaseYear  releaseDate  \
# 0  tt0118578                             Albela         2001  20 Apr 2001
# 1  tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2  tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3  tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4  tt0227194                         One 2 Ka 4         2001  30 Mar 2001
# 5  tt0238936                             Devdas         2002  12 Jul 2002
# 6  tt0247911        Aap Mujhe Achche Lagne Lage         2002  19 Apr 2002
# 7  tt0248126        Kabhi Khushi Kabhie Gham...         2001  14 Dec 2001
# 8  tt0248216                Na Tum Jaano Na Hum         2002  10 May 2002
# 9  tt0248617                         Yaadein...         2001  27 Jun 2001
#
#                          genre  \
# 0                      Romance
# 1  Adventure | Drama | Musical
# 2              Action | Comedy
# 3              Drama | Romance
# 4      Action | Comedy | Drama
# 5            Musical | Romance
# 6     Action | Drama | Romance
# 7    Drama | Musical | Romance
# 8     Comedy | Drama | Musical
# 9    Musical | Drama | Romance
#
#                                              writers  \
# 0  Honey Irani (screenplay) | Honey Irani (story)...
# 1  Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 2                                                NaN
# 3  K.S. Adiyaman | Arun Kumar (assistant dialogue...
# 4  Sanjay Chhel | Raaj Kumar Dahima (screenplay) ...
# 5  Saratchandra Chatterjee (based on the novel by...
# 6  Robin Bhatt (story) | Girish Dhamija (dialogue...
# 7           Karan Johar | Sheena Parikh (screenplay)
# 8         Pratibha Acharya (dialogue) | Arjun Sablok
# 9  Subhash Ghai (dialogue) | Subhash Ghai (screen...
#
#                                               actors  \
# 0  Govinda | Aishwarya Rai Bachchan | Jackie Shro...
# 1  Aamir Khan | Gracy Singh | Rachel Shelley | Pa...
# 2  Akshay Kumar | Sridevi | Gulshan Grover | Laxm...
# 3  Shah Rukh Khan | Madhuri Dixit | Salman Khan |...
# 4  Shah Rukh Khan | Juhi Chawla | Jackie Shroff |...
# 5  Shah Rukh Khan | Madhuri Dixit | Aishwarya Rai...
# 6  Hrithik Roshan | Ameesha Patel | Kiran Kumar |...
# 7  Amitabh Bachchan | Jaya Bhaduri | Shah Rukh Kh...
# 8  Saif Ali Khan | Hrithik Roshan | Esha Deol | A...
# 9  Jackie Shroff | Hrithik Roshan | Kareena Kapoo...
#
#                       directors  sequel  hitFlop
# 0                 Deepak Sareen     0.0        2
# 1            Ashutosh Gowariker     0.0        6
# 2  Pankaj Parashar | S.M. Iqbal     0.0        1
# 3                 K.S. Adiyaman     0.0        4
# 4             Shashilal K. Nair     0.0        1
# 5         Sanjay Leela Bhansali     0.0        6
# 6                  Vikram Bhatt     0.0        2
# 7                   Karan Johar     0.0        8
# 8                  Arjun Sablok     0.0        1
# 9                  Subhash Ghai     0.0        2

# %% [markdown]
# ## Handling Null Values For This Dataset

# %%
sns.heatmap(movies_df.isnull(), cbar=False)
plt.title('Null Values Heatmap')
plt.show()

# %%
movies_df.isnull().sum()
# Out:
# imdbId           0
# title            0
# releaseYear      0
# releaseDate     53
# genre            2
# writers        119
# actors           3
# directors        4
# sequel           3
# hitFlop          0
# dtype: int64

# %% [markdown]
# Above in the heatmap and table, we can see that there are quite a few null values in the dataset. so,we are required to handle these as well and to do so we will be deleting the rows with null values and for string parameters we will be replacing it with "no-columnName" .

# %%
movies_df['directors'].fillna('No Director', inplace=True)
movies_df['actors'].fillna('No actors', inplace=True)
movies_df['genre'].fillna('genre', inplace=True)
movies_df['writers'].fillna('No writers', inplace=True)
movies_df.dropna(subset=['releaseDate','sequel'],inplace=True)

# %%
movies_df.isnull().any()
# Out:
# imdbId         False
# title          False
# releaseYear    False
# releaseDate    False
# genre          False
# writers        False
# actors         False
# directors      False
# sequel         False
# hitFlop        False
# dtype: bool

# %% [markdown]
# Let us save our work before moving further.

# %%
import jovian

# %%
jovian.commit(files=['BollywoodActorRanking.csv','BollywoodMovieDetail.csv'],project=project_name)
# Out:
# [jovian] Updating notebook "devashish-dixit/analysis-on-the-top-ranked-bollywood-celebrities" on https://jovian.com
# [jovian] Uploading additional files...
# [jovian] Committed successfully! https://jovian.com/devashish-dixit/analysis-on-the-top-ranked-bollywood-celebrities
# 'https://jovian.com/devashish-dixit/analysis-on-the-top-ranked-bollywood-celebrities'

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# First we will begin analysis on the first dataset. Revisiting the data, let us see how it looked like again.

# %%
Bollywood_df
# Out:
#      actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 0        373        Aamir Khan          11       1170              9.44862
# 1        374    Shah Rukh Khan          23       2000              7.55009
# 2        375       Salman Khan          36       2340              5.40217
# 3        376      Katrina Kaif          17       1640              8.48082
# 4        377  Deepika Padukone          16       1080              5.64674
# ..       ...               ...         ...        ...                  ...
# 296      669       Achint Kaur           4         80              1.00000
# 297      670   Yuvika Chaudhry           5        100              1.00000
# 298      671      Pankaj Berry           5        100              1.00000
# 299      672      Varun Dhawan           0          0             80.00000
# 300      673     Nargis Fakhri           0          0             80.00000
#
#      googleHits  normalizedRating
# 0       2460000          10.00000
# 1       2670000           9.22674
# 2       3490000           9.20821
# 3       2120000           8.94852
# 4       3000000           8.62716
# ..          ...               ...
# 296           0           1.00000
# 297           0           1.00000
# 298           0           1.00000
# 299           0           4.74000
# 300           0           4.80000
#
# [301 rows x 7 columns]

# %% [markdown]
# Let us sort actors according to movies count and look at the top 10 actors that have produced most films.

# %%
Bollywood_df.sort_values('movieCount', ascending=False).head(10)
# Out:
#     actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 18      391      Akshay Kumar          54       2950              4.38768
# 14      387        Ajay Devgn          49       2320              3.67524
# 11      384  Amitabh Bachchan          48       2140              3.40489
# 36      409       Sanjay Dutt          43       1740              3.00202
# 83      456      Sunil Shetty          42       1530              2.60714
# 7       380    Kareena Kapoor          37       2200              4.86016
# 2       375       Salman Khan          36       2340              5.40217
# 77      450       Anupam Kher          36       1310              2.60326
# 6       379   Priyanka Chopra          36       1990              4.45109
# 42      415      Bipasha Basu          34       1570              3.56074
#
#     googleHits  normalizedRating
# 18     1960000           6.38048
# 14     2570000           6.87132
# 11     2770000           7.01130
# 36     1560000           5.00264
# 83      560000           3.30729
# 7      2940000           8.09065
# 2      3490000           9.20821
# 77      657000           3.44770
# 6      3130000           8.13686
# 42     1050000           4.57122

# %% [markdown]
# This data looks interesting,Let us plot a bar graph for each actors and the movie count.

# %%
sns.set(rc={'figure.figsize':(10,50)})
sns.barplot(x='movieCount', y='actorName', data=Bollywood_df).set(title="Actors and their movie counts");

# %% [markdown]
# Since this bar graph is too big, we extract a smaller part of the dataset. Let us take the top 50 for instance.

# %%
sns.set(rc={'figure.figsize':(14,11)})
sns.barplot(x='movieCount', y='actorName', data=Bollywood_df.sort_values('movieCount', ascending=False).head(50)).set(title="Actors and their movie counts");

# %% [markdown]
# Let us now plot the actors according to rating but for a subset of top 50 actors.

# %%
sns.set(rc={'figure.figsize':(14,11)})
sns.barplot(x='normalizedRating', y='actorName', data=Bollywood_df.sort_values('normalizedRating', ascending=False).head(50)).set(title="Actors and their ratings");

# %% [markdown]
# Let us now draw a histogram of number of normalized Rating made of the actors.

# %%
plt.title('number of normalized Rating made of the actors')
plt.xlabel('Actor rating')
plt.ylabel('number of actors')
plt.hist(Bollywood_df.normalizedRating);

# %% [markdown]
# This histogram implies that only a few actors were given the rating between 8 and 10 whereas a majority of the actors come in the range between 1 to 4.

# %% [markdown]
# ## Let us now use the second dataset

# %% [markdown]
# Let us revisit it

# %%
movies_df
# Out:
#          imdbId                              title  releaseYear  releaseDate  \
# 0     tt0118578                             Albela         2001  20 Apr 2001
# 1     tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2     tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3     tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4     tt0227194                         One 2 Ka 4         2001  30 Mar 2001
# ...         ...                                ...          ...          ...
# 1279  tt4121522               Shuruaat Ka Interval         2014  15 Aug 2014
# 1280  tt4187650                   Trip to Bhangarh         2014  28 Aug 2014
# 1281  tt4190220                           Zed Plus         2014  28 Nov 2014
# 1282  tt4219300                    Gollu aur Pappu         2014  21 Nov 2014
# 1283  tt4228746                                Zid         2014  28 Nov 2014
#
#                             genre  \
# 0                         Romance
# 1     Adventure | Drama | Musical
# 2                 Action | Comedy
# 3                 Drama | Romance
# 4         Action | Comedy | Drama
# ...                           ...
# 1279                        genre
# 1280                       Horror
# 1281                        genre
# 1282                       Comedy
# 1283                     Thriller
#
#                                                 writers  \
# 0     Honey Irani (screenplay) | Honey Irani (story)...
# 1     Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 2                                            No writers
# 3     K.S. Adiyaman | Arun Kumar (assistant dialogue...
# 4     Sanjay Chhel | Raaj Kumar Dahima (screenplay) ...
# ...                                                 ...
# 1279  Aarti S. Bagdi | Amrit Raj Gupta | Krishan Hoo...
# 1280                                         No writers
# 1281  Chandra Prakash Dwivedi (screen play and dialo...
# 1282                                         No writers
# 1283                   Vivek Agnihotri | Rohit Malhotra
#
#                                                  actors  \
# 0     Govinda | Aishwarya Rai Bachchan | Jackie Shro...
# 1     Aamir Khan | Gracy Singh | Rachel Shelley | Pa...
# 2     Akshay Kumar | Sridevi | Gulshan Grover | Laxm...
# 3     Shah Rukh Khan | Madhuri Dixit | Salman Khan |...
# 4     Shah Rukh Khan | Juhi Chawla | Jackie Shroff |...
# ...                                                 ...
# 1279  Kaivalya Chheda | Rajsekhar Aningi | Avidant B...
# 1280  Manish Choudhary | Suzanna Mukherjee | Poonam ...
# 1281  Adil Hussain | Ekavali Khanna | Kulbhushan Kha...
# 1282  Vir Das | Sandeepa Dhar | Rahul Handa | Dimple...
# 1283  Shradha Das | Mohan Kapoor | Mannara | Karanvi...
#
#                                               directors  sequel  hitFlop
# 0                                         Deepak Sareen     0.0        2
# 1                                    Ashutosh Gowariker     0.0        6
# 2                          Pankaj Parashar | S.M. Iqbal     0.0        1
# 3                                         K.S. Adiyaman     0.0        4
# 4                                     Shashilal K. Nair     0.0        1
# ...                                                 ...     ...      ...
# 1279  Aarti S. Bagdi | Amrit Raj Gupta | Krishan Hoo...     0.0        1
# 1280                                     Jitendra Pawar     0.0        1
# 1281                            Chandra Prakash Dwivedi     0.0        1
# 1282                                     Kabir Sadanand     0.0        1
# 1283                     Rohit Malhotra | Anubhav Sinha     0.0        2
#
# [1228 rows x 10 columns]

# %% [markdown]
# Here,Let us plot a scatter plot for hitflop parameter. remember, the hitFlop column value means
#
# 1 - Disaster 2 - Flop 3 - Below Average 4 - Average 5 - Semi Hit 6 - Hit 7 - Super Hit 8 - Blockbuster 9 - All-Time Blockbuster.

# %%
sns.scatterplot(movies_df.hitFlop, movies_df.index,s=100).set(title="scatter plot for hitflop parameter");
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# As we can see from the above scatter plot, majority of films are rated between 1 and 4, a moderate amount of films are rated between 5 and 7 and only a very few films can qualify the 8 & 9 mark with 9 only containing a countable 4 films which just shows how hard is to be an all time blockbuster film.

# %% [markdown]
# Plotting top 50 movies according to the hitflop rating parameter.

# %%
sns.set(rc={'figure.figsize':(14,11)})
sns.barplot(x='hitFlop', y='title', data=movies_df.sort_values('hitFlop', ascending=False).head(50)).set(title="top 50 movies according to the hitflop rating parameter");

# %% [markdown]
# Let us save and upload our work to Jovian before continuing

# %%
import jovian

# %%
jovian.commit(files=['BollywoodActorRanking.csv','BollywoodMovieDetail.csv'],project=project_name)
# Out:
# [jovian] Updating notebook "devashish-dixit/analysis-on-the-top-ranked-bollywood-celebrities" on https://jovian.com
# [jovian] Uploading additional files...
# [jovian] Committed successfully! https://jovian.com/devashish-dixit/analysis-on-the-top-ranked-bollywood-celebrities
# 'https://jovian.com/devashish-dixit/analysis-on-the-top-ranked-bollywood-celebrities'

# %% [markdown]
# ## Asking and Answering Questions

# %% [markdown]
# #### Q1: Which actor has the most google hits ?
# (google hits are the number of google searches for that actor)

# %% [markdown]
# Let us first look at a scatter plot of all data available for google hits to see the  trend.

# %%
plt.figure(figsize=(30,70))
plt.xticks(rotation=90)
sns.scatterplot(y=Bollywood_df.actorName, x=Bollywood_df.googleHits, s=100).set(title="google hits of actors");

# %% [markdown]
# As stated above, there are only a few actors that come close to 3.5*10^6 google hits.
# we can see a cluster of values lying in the range of 0 to 1.5*10^6 and lastly at the far right , we can see there are a lot of values for 0.0. Now that we have looked upon the trend,Let us see,which actor is leading in this criteria.

# %%
Bollywood_df.max().googleHits
# Out:
# 3490000

# %% [markdown]
# dataframe.max().column_name function is used to retrieve the max value from column value which we now use for querying the dataframe.

# %%
name=Bollywood_df[Bollywood_df.googleHits == Bollywood_df.max().googleHits].iat[0,1]

# %%
print('The actor with the most google hits is {}.'.format(name))
# Out:
# The actor with the most google hits is Salman Khan.

# %% [markdown]
# #### Q2: list of top 10 actors with least or no films?

# %%
Bollywood_df.sort_values('movieCount', ascending=True)
# Out:
#      actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 300      673     Nargis Fakhri           0          0                  NaN
# 299      672      Varun Dhawan           0          0                  NaN
# 242      615  Bharati Achrekar           4        120              1.97826
# 243      616  Ashish Vidyarthi           4        120              1.97826
# 86       459    Pavan Malhotra           4        240              4.91304
# ..       ...               ...         ...        ...                  ...
# 83       456      Sunil Shetty          42       1530              2.60714
# 36       409       Sanjay Dutt          43       1740              3.00202
# 11       384  Amitabh Bachchan          48       2140              3.40489
# 14       387        Ajay Devgn          49       2320              3.67524
# 18       391      Akshay Kumar          54       2950              4.38768
#
#      googleHits  normalizedRating
# 300           0           4.80000
# 299           0           4.74000
# 242           0           1.55754
# 243           0           1.55754
# 86            0           3.23016
# ..          ...               ...
# 83       560000           3.30729
# 36      1560000           5.00264
# 11      2770000           7.01130
# 14      2570000           6.87132
# 18      1960000           6.38048
#
# [301 rows x 7 columns]

# %% [markdown]
# As asked in the question, let us get the top 10 of the list by the use of .head() function

# %%
Bollywood_df.sort_values('movieCount', ascending=True).head(10)
# Out:
#      actorId          actorName  movieCount  ratingSum  normalizedMovieRank  \
# 300      673      Nargis Fakhri           0          0                  NaN
# 299      672       Varun Dhawan           0          0                  NaN
# 242      615   Bharati Achrekar           4        120              1.97826
# 243      616   Ashish Vidyarthi           4        120              1.97826
# 86       459     Pavan Malhotra           4        240              4.91304
# 80       453    Shraddha Kapoor           4        250              5.15761
# 250      623       Anuj Sawhney           4        110              1.73370
# 252      625        Neena Gupta           4        100              1.48913
# 253      626   Gajendra Chouhan           4        100              1.48913
# 254      627  Perizaad Zorabian           4        100              1.48913
#
#      googleHits  normalizedRating
# 300           0           4.80000
# 299           0           4.74000
# 242           0           1.55754
# 243           0           1.55754
# 86            0           3.23016
# 80            0           3.36954
# 250           0           1.41815
# 252           0           1.27877
# 253           0           1.27877
# 254           0           1.27877

# %% [markdown]
# Let us acquire the number of distinct movie count for the table , if the number is too small there is no point in visualizing it.

# %%
Bollywood_df.sort_values('movieCount', ascending=True).head(10).movieCount.nunique()
# Out:
# 2

# %% [markdown]
# Now , It would be a great idea to plot these actors with respect to their normalized Rating and setting moviecount as hue for getting better insights.

# %%
sns.barplot(x='normalizedRating', y='actorName', hue='movieCount', data=Bollywood_df.sort_values('movieCount', ascending=True).head(10)).set(title="Actors with least or no films and their movie counts");

# %% [markdown]
# Now,let us also retrieve the actors name as a normal python list which may come in handy in further analysis.

# %%
answer2 = (Bollywood_df.sort_values('movieCount', ascending=True).head(10).actorName).tolist()

# %%
print(answer2)
# Out:
# ['Nargis Fakhri', 'Varun Dhawan', 'Bharati Achrekar', 'Ashish Vidyarthi', 'Pavan Malhotra', 'Shraddha Kapoor', 'Anuj Sawhney', 'Neena Gupta', 'Gajendra Chouhan', 'Perizaad Zorabian']

# %% [markdown]
# #### Q3: What are the top 10 most popular genre in bollywood movies ?

# %% [markdown]
# Let us retrieve the unique genre types and their respective film count .

# %%
labels = movies_df['genre'].value_counts()[:10].index.tolist()

# %%
data = movies_df['genre'].value_counts()[:10].tolist()

# %% [markdown]
# The best way to represent the data would be with the help of a pie chart that will clearly tell us about its distribution.

# %%
plt.title("10 most popular genre in bollywood films")
plt.pie(data, labels = labels, autopct='%.0f%%');

# %% [markdown]
# As it is evident from the above pie chart , Drama is the most popular genre of bollywood films followed by composite of comedy|drama|romance and comedy|drama films.

# %% [markdown]
# #### Q4: How many films have at least one sequel and how did the sequels performed on theatres?

# %%
movies_df[movies_df.sequel!=0]
# Out:
#          imdbId                                title  releaseYear  \
# 118   tt0337633   Hathyar: Face to Face with Reality         2002
# 220   tt0383719                             Xcuse Me         2003
# 283   tt0419058                      Phir Hera Pheri         2006
# 307   tt0432637                               Krrish         2006
# 324   tt0441048                              Dhoom:2         2006
# 371   tt0456144                 Lage Raho Munna Bhai         2006
# 390   tt0461936                                  Don         2006
# 451   tt0490210                           Sarkar Raj         2008
# 555   tt1029231                             Krrish 3         2013
# 574   tt1092005                      Golmaal Returns         2008
# 601   tt1169841                    Return of Hanuman         2007
# 691   tt1283926                  My Friend Ganesha 2         2008
# 692   tt1285241                                Don 2         2011
# 717   tt1340838          Raaz: The Mystery Continues         2009
# 731   tt1375789                               Race 2         2013
# 787   tt1562859                            Golmaal 3         2010
# 818   tt1612611                             Phoonk 2         2010
# 886   tt1796564                  My Friend Ganesha 3         2010
# 901   tt1833673                             Dhoom: 3         2013
# 919   tt1891884  Once Upon a Time in Mumbai Dobaara!         2013
# 933   tt1918965                             Murder 2         2011
# 942   tt1939654                          Bheja Fry 2         2011
# 960   tt1980986                          Housefull 2         2012
# 976   tt2027138             Kyaa Super Kool Hain Hum         2012
# 1005  tt2112131                            Dabangg 2         2012
# 1012  tt2140315          Raaz 3: The Third Dimension         2012
# 1039  tt2203308                           Aashiqui 2         2013
# 1048  tt2222550                   1920: Evil Returns         2012
# 1054  tt2226666                               Jism 2         2012
# 1071  tt2278422              Kamaal Dhamaal Malamaal         2012
# 1075  tt2301155                   Shootout at Wadala         2013
# 1079  tt2309764                      Singham Returns         2014
# 1085  tt2319889                             Jannat 2         2012
# 1110  tt2362778      Saheb Biwi Aur Gangster Returns         2013
# 1127  tt2406636                        Bhoot Returns         2012
# 1131  tt2429640                             Murder 3         2013
# 1137  tt2476154                          Grand Masti         2013
# 1138  tt2510874                Yamla Pagla Deewana 2         2013
# 1147  tt2609218                         Ragini MMS 2         2014
# 1159  tt2675978                         Dedh Ishqiya         2014
# 1203  tt3059106                              Satya 2         2013
# 1217  tt3302962               Shaadi Ke Side Effects         2014
# 1247  tt3531852                   Bhoothnath Returns         2014
# 1255  tt3619772                         Hate Story 2         2014
#
#       releaseDate                           genre  \
# 118   18 Oct 2002       Action | Thriller | Crime
# 220   26 Sep 2003                          Comedy
# 283   09 Jun 2006                  Comedy | Crime
# 307   23 Jun 2006    Action | Adventure | Romance
# 324   24 Nov 2006               Action | Thriller
# 371   01 Sep 2006        Comedy | Drama | Romance
# 390   20 Oct 2006       Action | Crime | Thriller
# 451   06 Jun 2008          Action | Crime | Drama
# 555   01 Nov 2013                 Action | Sci-Fi
# 574   29 Oct 2008          Comedy | Crime | Drama
# 601   28 Dec 2007  Animation | Action | Adventure
# 691   22 Aug 2008              Animation | Family
# 692   23 Dec 2011          Action | Crime | Drama
# 717   23 Jan 2009        Drama | Horror | Mystery
# 731   25 Jan 2013          Action | Crime | Drama
# 787   05 Nov 2010                 Action | Comedy
# 818   16 Apr 2010        Drama | Horror | Mystery
# 886   26 Mar 2010      Animation | Comedy | Drama
# 901   20 Dec 2013       Action | Crime | Thriller
# 919   15 Aug 2013          Action | Crime | Drama
# 933   08 Jul 2011          Action | Crime | Drama
# 942   17 Jun 2011                  Comedy | Drama
# 960   05 Apr 2012                Comedy | Romance
# 976   27 Jul 2012                          Comedy
# 1005  21 Dec 2012         Action | Comedy | Drama
# 1012  07 Sep 2012     Horror | Romance | Thriller
# 1039  26 Apr 2013         Drama | Music | Musical
# 1048  02 Nov 2012        Drama | Horror | Romance
# 1054  03 Aug 2012      Drama | Romance | Thriller
# 1071  28 Sep 2012                          Comedy
# 1075  03 May 2013                  Action | Crime
# 1079  15 Aug 2014                          Action
# 1085  04 May 2012        Crime | Drama | Thriller
# 1110  08 Mar 2013          Action | Crime | Drama
# 1127  12 Oct 2012                          Horror
# 1131  15 Feb 2013                        Thriller
# 1137  13 Sep 2013        Comedy | Drama | Romance
# 1138  07 Jun 2013         Action | Comedy | Drama
# 1147  21 Mar 2014     Horror | Romance | Thriller
# 1159  10 Jan 2014        Comedy | Drama | Romance
# 1203  08 Nov 2013                           Crime
# 1217  28 Feb 2014                Comedy | Romance
# 1247  11 Apr 2014        Comedy | Drama | Fantasy
# 1255  18 Jul 2014      Drama | Romance | Thriller
#
#                                                 writers  \
# 118   Praveen Bhardwaj (lyrics) | Dev Kohli (lyrics)...
# 220                                          No writers
# 283                                         Neeraj Vora
# 307   Robin Bhatt (screenplay) | Sachin Bhowmick (sc...
# 324   Vijay Krishna Acharya (screenplay) | Vijay Kri...
# 371   Vidhu Vinod Chopra (screenplay) | Rajkumar Hir...
# 390   Salim Khan (based on an original screenplay by...
# 451                                     Prashant Pandey
# 555   Rakesh Roshan (story) | Robin Bhatt (screenpla...
# 574   Indie (lyrics) | Rumi Jaffery | Ashiesh Pandit...
# 601                                      Anurag Kashyap
# 691                Rajiv S. Ruia (story) | S. Sachinder
# 692   Farhan Akhtar (dialogue) | Farhan Akhtar (stor...
# 717   Kumaar (lyrics) | Sayeed Qadri (lyrics) | Shag...
# 731   Shiraz Ahmed (screenplay) | Kiran Kotrial (dia...
# 787   Robin Bhatt (script consultant) | Farhad (dial...
# 818                                     Milind Gadagkar
# 886   Shabbir Ahmed (lyrics) | Rajiv S. Ruia (story)...
# 901   Vijay Krishna Acharya (story) | Aditya Chopra ...
# 919                                         Rajat Arora
# 933                     Mahesh Bhatt | Shagufta Rafique
# 942   Sagar Ballary (screenplay) | Sharat Katariya (...
# 960   Farhad (dialogue) | Farhad (screenplay) | Tush...
# 976   Sukhmani Sadana (dialogue revisor) | Sachin Yardi
# 1005                                       Dilip Shukla
# 1012                                   Shagufta Rafique
# 1039                                   Shagufta Rafique
# 1048                                       Vikram Bhatt
# 1054  Mahesh Bhatt (screenplay) | Mahesh Bhatt | Sha...
# 1071                                         No writers
# 1075  Sanjay Bhatia (screenplay) | Abhijeet Deshpand...
# 1079  Rohit Shetty (story) | Yunus Sajawal (screenpl...
# 1085            Kapil Chopra | Sanjay Masoom (dialogue)
# 1110  Tigmanshu Dhulia (screenplay) | Tigmanshu Dhul...
# 1127                                         No writers
# 1131  Mahesh Bhatt | Hatem Khraiche (original film "...
# 1137  Tushar Hiranandani (story) | Milap Zaveri (dia...
# 1138   Jasvinder Bath (screenplay) | Lynda Deol (story)
# 1147  Tanveer Bookwala (story) | Ishita Moitra (dial...
# 1159  Vishal Bhardwaj (dialogue) | Vishal Bhardwaj (...
# 1203  Radhika Anand | Kary Arora (lyrics) | Meeraqh ...
# 1217  Saket Chaudhary (screenplay) | Saket Chaudhary...
# 1247  Piyush Gupta | Shreyas Jain (additional script...
# 1255  Madhuri Banerjee (screenplay) | Girish Dhamija...
#
#                                                  actors  \
# 118   Sanjay Dutt | Shilpa Shetty | Sharad S. Kapoor...
# 220   Sharman Joshi | Sahil Khan | Anil Chaudhary | ...
# 283   Akshay Kumar | Sunil Shetty | Paresh Rawal | B...
# 307   Rekha | Hrithik Roshan | Priyanka Chopra | Sha...
# 324   Abhishek Bachchan | Uday Chopra | Hrithik Rosh...
# 371   Sanjay Dutt | Arshad Warsi | Vidya Balan | Bom...
# 390   Shah Rukh Khan | Priyanka Chopra | Arjun Rampa...
# 451   Amitabh Bachchan | Abhishek Bachchan | Aishwar...
# 555   Hrithik Roshan | Amitabh Bachchan | Priyanka C...
# 574   Amrita Arora | Leigh Barwell | Robin Bhatt | A...
# 601                                           No actors
# 691   Harsh Chhaya | Kurush Deboo | Bhairavi Goswami...
# 692   Shah Rukh Khan | Priyanka Chopra | Hrithik Ros...
# 717   Kangana Ranaut | Adhyayan Suman | Emraan Hashm...
# 731   Anil Kapoor | Saif Ali Khan | John Abraham | D...
# 787   Mithun Chakraborty | Ajay Devgn | Kareena Kapo...
# 818   Sudeep | Amruta Khanvilkar | Ahsaas Channa | A...
# 886   Makarand Anaspure | Krishna Bhatt | Sonika Gil...
# 901   Aamir Khan | Katrina Kaif | Tabrett Bethell | ...
# 919   Akshay Kumar | Pitobash | Sonakshi Sinha | Imr...
# 933   Jacqueline Fernandez | Yana Gupta | Emraan Has...
# 942   Vinay Pathak | Kay Kay Menon | Minissha Lamba ...
# 960   Akshay Kumar | Asin | John Abraham | Jacquelin...
# 976   Anupam Kher | Ritesh Deshmukh | Rohit Shetty |...
# 1005  Salman Khan | Sonakshi Sinha | Prakash Raj | V...
# 1012  Emraan Hashmi | Bipasha Basu | Esha Gupta | Ma...
# 1039  Aditya Roy Kapoor | Shraddha Kapoor | Shaad Ra...
# 1048  Vicky Ahuja | Tia Bajpai | Sharad Kelkar | Vid...
# 1054  Randeep Hooda | Sunny Leone | Arunoday Singh |...
# 1071  Asrani | Madhurima Banerjee | Shakti Kapoor | ...
# 1075  John Abraham | Kangana Ranaut | Anil Kapoor | ...
# 1079  Kareena Kapoor | Ajay Devgn | Anupam Kher | Yo...
# 1085  Mohammed Zeeshan Ayyub | Viren Basoya | Manish...
# 1110  Raj Babbar | Mahie Gill | Mugdha Godse | Rajiv...
# 1127  J.D. Chakravarthi | Nitin Jadhav | Manisha Koi...
# 1131  Randeep Hooda | Aditi Rao Hydari | Sara Loren ...
# 1137  Ritesh Deshmukh | Vivek Oberoi | Aftab Shivdas...
# 1138  Dharmendra | Sunny Deol | Bobby Deol | Neha Sh...
# 1147  Sunny Leone | Saahil Prem | Parvin Dabas | San...
# 1159  Naseeruddin Shah | Madhuri Dixit | Arshad Wars...
# 1203  Puneet Singh Ratn | Sharvanand | Anaika Soti |...
# 1217  Farhan Akhtar | Vidya Balan | Vir Das | Ram Ka...
# 1247  Amitabh Bachchan | Boman Irani | Parth Bhalera...
# 1255  Sushant Singh | Surveen Chawla | Jay Bhanushal...
#
#                                               directors  sequel  hitFlop
# 118                                    Mahesh Manjrekar     1.0        2
# 220                                          N. Chandra     1.0        1
# 283                                         Neeraj Vora     1.0        7
# 307                                       Rakesh Roshan     1.0        8
# 324                                       Sanjay Gadhvi     1.0        8
# 371                                     Rajkumar Hirani     1.0        8
# 390                                       Farhan Akhtar     1.0        6
# 451                                     Ram Gopal Varma     1.0        3
# 555                                       Rakesh Roshan     1.0        8
# 574                                        Rohit Shetty     1.0        6
# 601                                      Anurag Kashyap     1.0        1
# 691                                       Rajiv S. Ruia     1.0        1
# 692                                       Farhan Akhtar     1.0        6
# 717                                          Mohit Suri     1.0        5
# 731   Abbas Alibhai Burmawalla | Mastan Alibhai Burm...     1.0        5
# 787                                        Rohit Shetty     1.0        8
# 818                                     Milind Gadagkar     1.0        2
# 886                                       Rajiv S. Ruia     1.0        1
# 901                               Vijay Krishna Acharya     1.0        9
# 919                                       Milan Luthria     1.0        1
# 933                                          Mohit Suri     1.0        7
# 942                                       Sagar Ballary     1.0        3
# 960                                          Sajid Khan     1.0        7
# 976                                        Sachin Yardi     1.0        5
# 1005                                        Arbaaz Khan     1.0        8
# 1012                                       Vikram Bhatt     1.0        7
# 1039                                         Mohit Suri     1.0        8
# 1048                                      Bhushan Patel     1.0        5
# 1054                                        Pooja Bhatt     1.0        5
# 1071                                       Priyadarshan     1.0        1
# 1075                                       Sanjay Gupta     1.0        4
# 1079                                       Rohit Shetty     1.0        7
# 1085                                     Kunal Deshmukh     1.0        5
# 1110                                   Tigmanshu Dhulia     1.0        3
# 1127                                    Ram Gopal Varma     1.0        2
# 1131                                      Vishesh Bhatt     1.0        2
# 1137                                        Indra Kumar     1.0        7
# 1138                                     Sangeeth Sivan     1.0        2
# 1147                                      Bhushan Patel     1.0        6
# 1159                                   Abhishek Chaubey     1.0        2
# 1203                                    Ram Gopal Varma     1.0        1
# 1217                                    Saket Chaudhary     1.0        2
# 1247                                      Nitesh Tiwari     1.0        3
# 1255                                      Vishal Pandya     2.0        4

# %% [markdown]
# Let us plot these movies with their respective hitFlop rating to infer how did they perform on box office.

# %%
sns.barplot(x ='hitFlop', y ='title',hue='sequel', data=movies_df[movies_df.sequel!=0]).set(title="films with sequels and their ratings");

# %% [markdown]
# As stated in the above bar graph,Dhoom 3 performed the best out of all movies with a hitFlop rating of 9 which means it was an all time blockbuster. note that we used sequel as hue and we can see there are only  2 distinct values 1,2. Now,let us also give the total number of films with a sequel.

# %%
len(movies_df[movies_df.sequel!=0])
# Out:
# 44

# %%
print('There are {} films which have at least one sequel.'.format(len(movies_df[movies_df.sequel!=0])))
# Out:
# There are 44 films which have at least one sequel.

# %% [markdown]
# #### Q5:What inference can be made from the dataset about the time gap between the release of all-time blockbusters, and how has the time gap changed over the years?

# %%
movies_df[movies_df.hitFlop==9]
# Out:
#          imdbId                 title  releaseYear  releaseDate  \
# 32    tt0284137  Gadar: Ek Prem Katha         2001  15 Jun 2001
# 625   tt1187043              3 Idiots         2009  25 Dec 2009
# 901   tt1833673              Dhoom: 3         2013  20 Dec 2013
# 1092  tt2338151                    PK         2014  19 Dec 2014
#
#                           genre  \
# 32     Action | Drama | Romance
# 625              Comedy | Drama
# 901   Action | Crime | Thriller
# 1092   Comedy | Drama | Fantasy
#
#                                                 writers  \
# 32                                    Shaktimaan Talwar
# 625   Rajkumar Hirani | Abhijit Joshi | Vidhu Vinod ...
# 901   Vijay Krishna Acharya (story) | Aditya Chopra ...
# 1092  Rajkumar Hirani | Abhijit Joshi | Sreerag Nambiar
#
#                                                  actors  \
# 32    Sunny Deol | Ameesha Patel | Amrish Puri | Lil...
# 625   Aamir Khan | Kareena Kapoor | Madhavan | Sharm...
# 901   Aamir Khan | Katrina Kaif | Tabrett Bethell | ...
# 1092  Aamir Khan | Anushka Sharma | Sanjay Dutt | Bo...
#
#                   directors  sequel  hitFlop
# 32              Anil Sharma     0.0        9
# 625         Rajkumar Hirani     0.0        9
# 901   Vijay Krishna Acharya     1.0        9
# 1092        Rajkumar Hirani     0.0        9

# %%
ans = movies_df[movies_df.hitFlop==9]

# %% [markdown]
# The number of movies are very limited, so let us use a line graph to plot movie titles and release year to get to know the trend visually.

# %%
plt.plot(ans.releaseYear, ans.title, 's--b')

plt.xlabel('Year')
plt.ylabel('Title')

plt.title("All time blockbusters");

# %% [markdown]
# Here, we make an important inference with the help of the line graph,the time gap between the release of all time blockbusters keep getting reduced. the time gap between Gadar: Ek Prem Katha and 3 Idiots is comparatively huge, in comparision to the time gap between 3 Idiots and  Dhoom: 3 and the time gap was dramatically reduced in the case of PK.

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
import jovian

# %%
jovian.commit(files=['BollywoodActorRanking.csv','BollywoodMovieDetail.csv'],project=project_name)

# %% [markdown]
# ## Inferences and Conclusion
#
# After conducting exploratory data analysis on Bollywood top ranked actors as well as the movie  dataset, several key insights can be drawn. The trend between 2001 and 2014 can be studied to predict best actors and directors. Important questions were asked and can be used to infer new questions and subsequently, their answers.Pandas, Matplotlib, and Seaborn was used for  providing valuable insights and visualizations of the data. Pandas was used to clean and manipulate the data, Matplotlib,seaborn was used to create data visualizations.

# %%
import jovian

# %%
jovian.commit(files=['BollywoodActorRanking.csv','BollywoodMovieDetail.csv'],project=project_name)
# Out:
# [jovian] Updating notebook "devashish-dixit/analysis-on-the-top-ranked-bollywood-celebrities" on https://jovian.com
# [jovian] Uploading additional files...
# [jovian] Committed successfully! https://jovian.com/devashish-dixit/analysis-on-the-top-ranked-bollywood-celebrities
# 'https://jovian.com/devashish-dixit/analysis-on-the-top-ranked-bollywood-celebrities'

# %% [markdown]
# ## References and Future Work
#
# - **Dataset** - https://github.com/calci/bollywood-movie-dataset
# - https://stackoverflow.com/questions/31594549/how-to-change-the-figure-size-of-a-seaborn-axes-or-figure-level-plot
# - https://sparkbyexamples.com/pandas/pandas-get-cell-value-from-dataframe/#:~:text=In%20Pandas%2C%20DataFrame.loc%5B%5D,Duration%20column%20(3rd%20column).&text=Copy-,Yields%20below%20output.,'%5D%20returns%20a%20pandas%20Series.
# - https://www.geeksforgeeks.org/python-pandas-series-tolist/
# - https://www.geeksforgeeks.org/how-to-count-occurrences-of-specific-value-in-pandas-column/
# - https://www.statology.org/seaborn-pie-chart/#:~:text=Seaborn%20Color%20Palette-,The%20following%20code%20shows%20how%20to%20create%20a%20pie%20chart,palette%20to%20use%20colors%20%3D%20sns.
# - https://stackoverflow.com/questions/48590268/pandas-get-the-most-frequent-values-of-a-column
# - https://www.geeksforgeeks.org/how-to-add-a-title-to-seaborn-plots/
#
#
# ### Future work
# - EDA on Movies & TV Shows available on OTT platforms
# - Movie catalog  and rating System using python

# %%
import jovian

# %%
jovian.commit(files=['BollywoodActorRanking.csv','BollywoodMovieDetail.csv'],project=project_name)
